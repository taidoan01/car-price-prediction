# %%
import pandas as pd

# %% [markdown]
# Load Data thô

# %%
cars_data = pd.read_csv('cars_dataset_15_manufactures.csv',sep = ';',encoding='utf-8')
cars_data
# Out:
#                                                      url                 name  \
# 0      https://www.cars-data.com/en/aiways-u5-standaa...  Aiways U5 Standaard
# 1      https://www.cars-data.com/en/aiways-u5-premium...    Aiways U5 Premium
# 2      https://www.cars-data.com/en/aiways-u5-showroo...   Aiways U5 Showroom
# 3      https://www.cars-data.com/en/subaru-svx-specs/...           Subaru SVX
# 4      https://www.cars-data.com/en/subaru-e-wagon-aw...   Subaru E-wagon AWD
# ...                                                  ...                  ...
# 16128  https://www.cars-data.com/en/tvr-sagaris-specs...          TVR Sagaris
# 16129  https://www.cars-data.com/en/tvr-tuscan-specs/...           TVR Tuscan
# 16130  https://www.cars-data.com/en/tvr-tuscan-s-spec...         TVR Tuscan S
# 16131  https://www.cars-data.com/en/tvr-griffith-500-...     TVR Griffith 500
# 16132  https://www.cars-data.com/en/tvr-griffith-400-...     TVR Griffith 400
#
#         model   brand    price eLabel                bodyType   length  \
# 0      Aiways  Aiways   39.083      a  5-doors, suv/crossover  4680 mm
# 1      Aiways  Aiways   42.934      a  5-doors, suv/crossover  4680 mm
# 2      Aiways  Aiways   40.934      a  5-doors, suv/crossover  4680 mm
# 3      Subaru  Subaru   53.090    NaN          3-doors, coupé  4625 mm
# 4      Subaru  Subaru   17.241    NaN            5-doors, mpv  3525 mm
# ...       ...     ...      ...    ...                     ...      ...
# 16128     TVR     TVR  134.500    NaN    2-doors, convertible  4060 mm
# 16129     TVR     TVR  105.500    NaN    2-doors, convertible  4235 mm
# 16130     TVR     TVR  109.900    NaN    2-doors, convertible  4235 mm
# 16131     TVR     TVR   71.187    NaN    2-doors, convertible  3892 mm
# 16132     TVR     TVR   63.473    NaN    2-doors, convertible  3892 mm
#
#         height    width  ...  fuelCapacity fuelConsumption     speed  payload  \
# 0      1700 mm  1865 mm  ...           NaN             NaN  150 km/h   #NAME?
# 1      1700 mm  1865 mm  ...           NaN             NaN  150 km/h   #NAME?
# 2      1700 mm  1865 mm  ...           NaN             NaN  150 km/h   #NAME?
# 3      1300 mm  1770 mm  ...       3319 cc       - l/100km  235 km/h   435 kg
# 4      1925 mm  1415 mm  ...       1189 cc       - l/100km  128 km/h   670 kg
# ...        ...      ...  ...           ...             ...       ...      ...
# 16128  1175 mm  1770 mm  ...       3996 cc       - l/100km  295 km/h   #NAME?
# 16129  1200 mm  1810 mm  ...       3605 cc       - l/100km  290 km/h   #NAME?
# 16130  1200 mm  1810 mm  ...       3996 cc       - l/100km  314 km/h   #NAME?
# 16131  1205 mm  1943 mm  ...       4997 cc       - l/100km  267 km/h   170 kg
# 16132  1205 mm  1943 mm  ...       3950 cc       - l/100km  235 km/h   170 kg
#
#       trailerWeight    vEengineType  vEfuelType vEengineDisplacement  \
# 0           1720 kg  electric motor         NaN                  NaN
# 1           1770 kg  electric motor         NaN                  NaN
# 2           1770 kg  electric motor         NaN                  NaN
# 3           1610 kg     fuel engine    gasoline              3319 cc
# 4            930 kg     fuel engine    gasoline              1189 cc
# ...             ...             ...         ...                  ...
# 16128       1078 kg     fuel engine    gasoline              3996 cc
# 16129       1100 kg     fuel engine    gasoline              3605 cc
# 16130       1150 kg     fuel engine    gasoline              3996 cc
# 16131       1080 kg     fuel engine    gasoline              4997 cc
# 16132       1080 kg     fuel engine    gasoline              3950 cc
#
#         vEenginePower torque
# 0      electric motor    310
# 1      electric motor    310
# 2      electric motor    310
# 3         fuel engine    309
# 4         fuel engine     97
# ...               ...    ...
# 16128     fuel engine    420
# 16129     fuel engine    390
# 16130     fuel engine    420
# 16131     fuel engine    490
# 16132     fuel engine   n.b.
#
# [16133 rows x 34 columns]

# %%
cars_data.columns
# Out:
# Index(['url', 'name', 'model', 'brand', 'price', 'eLabel', 'bodyType',
#        'length', 'height', 'width', 'weight', 'weightTotal', 'emissionsCO2',
#        'modelDate', 'fuelType', 'numberOfAxles', 'numberOfDoors',
#        'numberOfForwardGears', 'seatingCapacity', 'vehicleTransmission',
#        'cargoVolume', 'roofLoad', 'accelerationTime',
#        'driveWheelConfiguration', 'fuelCapacity', 'fuelConsumption', 'speed',
#        'payload', 'trailerWeight', 'vEengineType', 'vEfuelType',
#        'vEengineDisplacement', 'vEenginePower', 'torque'],
#       dtype='object')

# %% [markdown]
# Loại bỏ những cột không cần thiết

# %%
col_drop = {'url','model', 'eLabel',
            'bodyType','weight','emissionsCO2', 
            'driveWheelConfiguration','vEfuelType',
            'vEenginePower','fuelConsumption'}
cars_data = cars_data.drop(col_drop,axis = 1)
cars_data
# Out:
#                       name   brand    price   length   height    width  \
# 0      Aiways U5 Standaard  Aiways   39.083  4680 mm  1700 mm  1865 mm
# 1        Aiways U5 Premium  Aiways   42.934  4680 mm  1700 mm  1865 mm
# 2       Aiways U5 Showroom  Aiways   40.934  4680 mm  1700 mm  1865 mm
# 3               Subaru SVX  Subaru   53.090  4625 mm  1300 mm  1770 mm
# 4       Subaru E-wagon AWD  Subaru   17.241  3525 mm  1925 mm  1415 mm
# ...                    ...     ...      ...      ...      ...      ...
# 16128          TVR Sagaris     TVR  134.500  4060 mm  1175 mm  1770 mm
# 16129           TVR Tuscan     TVR  105.500  4235 mm  1200 mm  1810 mm
# 16130         TVR Tuscan S     TVR  109.900  4235 mm  1200 mm  1810 mm
# 16131     TVR Griffith 500     TVR   71.187  3892 mm  1205 mm  1943 mm
# 16132     TVR Griffith 400     TVR   63.473  3892 mm  1205 mm  1943 mm
#
#       weightTotal  modelDate  fuelType  numberOfAxles  ...  cargoVolume  \
# 0               -       2020       NaN              2  ...   432-1555 l
# 1               -       2020       NaN              2  ...   432-1555 l
# 2               -       2020       NaN              2  ...   432-1555 l
# 3            2045       1992  gasoline              2  ...    240-466 l
# 4            1600       1993  gasoline              2  ...       #NAME?
# ...           ...        ...       ...            ...  ...          ...
# 16128           -       2006  gasoline              2  ...        495 l
# 16129           -       2003  gasoline              2  ...        275 l
# 16130           -       2003  gasoline              2  ...        275 l
# 16131        1250       1994  gasoline              2  ...        255 l
# 16132        1250       1994  gasoline              2  ...        255 l
#
#       roofLoad accelerationTime fuelCapacity     speed payload trailerWeight  \
# 0           75              7,5          NaN  150 km/h  #NAME?       1720 kg
# 1           75              7,8          NaN  150 km/h  #NAME?       1770 kg
# 2           75              7,8          NaN  150 km/h  #NAME?       1770 kg
# 3           50              8,6      3319 cc  235 km/h  435 kg       1610 kg
# 4           70             17,2      1189 cc  128 km/h  670 kg        930 kg
# ...        ...              ...          ...       ...     ...           ...
# 16128        -              3,7      3996 cc  295 km/h  #NAME?       1078 kg
# 16129        -              4,2      3605 cc  290 km/h  #NAME?       1100 kg
# 16130        -              3,9      3996 cc  314 km/h  #NAME?       1150 kg
# 16131        -              4,1      4997 cc  267 km/h  170 kg       1080 kg
# 16132        -              4,8      3950 cc  235 km/h  170 kg       1080 kg
#
#          vEengineType vEengineDisplacement torque
# 0      electric motor                  NaN    310
# 1      electric motor                  NaN    310
# 2      electric motor                  NaN    310
# 3         fuel engine              3319 cc    309
# 4         fuel engine              1189 cc     97
# ...               ...                  ...    ...
# 16128     fuel engine              3996 cc    420
# 16129     fuel engine              3605 cc    390
# 16130     fuel engine              3996 cc    420
# 16131     fuel engine              4997 cc    490
# 16132     fuel engine              3950 cc   n.b.
#
# [16133 rows x 24 columns]

# %% [markdown]
# Loại bỏ đơn vị của các thuộc tính dạng số

# %%
cars_data['length'] = cars_data['length'].map(lambda x: x.rstrip('mm'))
cars_data['height'] = cars_data['height'].map(lambda x: x.rstrip('mm'))
cars_data['width'] = cars_data['width'].map(lambda x: x.rstrip('mm'))
cars_data['fuelCapacity'] = cars_data['fuelCapacity'].str.replace(r'\D','')
cars_data['vEengineDisplacement'] = cars_data['vEengineDisplacement'].str.replace(r'\D','')
cars_data['cargoVolume'] = cars_data['cargoVolume'].map(lambda x: x.strip('l'))
# Out:
# <ipython-input-5-5776eba5f821>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   cars_data['fuelCapacity'] = cars_data['fuelCapacity'].str.replace(r'\D','')
# <ipython-input-5-5776eba5f821>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   cars_data['vEengineDisplacement'] = cars_data['vEengineDisplacement'].str.replace(r'\D','')

# %% [markdown]
# Hàm để xử lý cột cargoVolume

# %%
def cvtFloat_cargoVolume(x):
    temp = x.split()[0]
    temp = temp.replace('-', ' ')
    temp = temp.split()
    if len(temp) > 0:
        temp = temp[-1]
    else:
        temp = x
    val = None
    try:
        val = float(temp)
    except ValueError:
        return val
    return val

# %%
cars_data['cargoVolume'] = cars_data['cargoVolume'].apply(cvtFloat_cargoVolume)

# %%
cars_data['speed'] = cars_data['speed'].map(lambda x: x.rstrip('km/h'))
cars_data['payload'] = cars_data['payload'].map(lambda x: x.rstrip('kg'))
cars_data['trailerWeight'] = cars_data['trailerWeight'].map(lambda x: x.rstrip('kg'))

# %% [markdown]
# Hàm ép kiểu float

# %%
def cvtFloat(x):
    if type(x) == str:
        temp = x.replace(',', '.').split()[0]
    else:
        temp = x
    val = None
    try:
        val = float(temp)
    except ValueError:
        return val
    return val

# %%
cars_data['accelerationTime'] = cars_data['accelerationTime'].apply(cvtFloat)

# %%
cars_data
# Out:
#                       name   brand    price length height  width weightTotal  \
# 0      Aiways U5 Standaard  Aiways   39.083  4680   1700   1865            -
# 1        Aiways U5 Premium  Aiways   42.934  4680   1700   1865            -
# 2       Aiways U5 Showroom  Aiways   40.934  4680   1700   1865            -
# 3               Subaru SVX  Subaru   53.090  4625   1300   1770         2045
# 4       Subaru E-wagon AWD  Subaru   17.241  3525   1925   1415         1600
# ...                    ...     ...      ...    ...    ...    ...         ...
# 16128          TVR Sagaris     TVR  134.500  4060   1175   1770            -
# 16129           TVR Tuscan     TVR  105.500  4235   1200   1810            -
# 16130         TVR Tuscan S     TVR  109.900  4235   1200   1810            -
# 16131     TVR Griffith 500     TVR   71.187  3892   1205   1943         1250
# 16132     TVR Griffith 400     TVR   63.473  3892   1205   1943         1250
#
#        modelDate  fuelType  numberOfAxles  ...  cargoVolume roofLoad  \
# 0           2020       NaN              2  ...       1555.0       75
# 1           2020       NaN              2  ...       1555.0       75
# 2           2020       NaN              2  ...       1555.0       75
# 3           1992  gasoline              2  ...        466.0       50
# 4           1993  gasoline              2  ...          NaN       70
# ...          ...       ...            ...  ...          ...      ...
# 16128       2006  gasoline              2  ...        495.0        -
# 16129       2003  gasoline              2  ...        275.0        -
# 16130       2003  gasoline              2  ...        275.0        -
# 16131       1994  gasoline              2  ...        255.0        -
# 16132       1994  gasoline              2  ...        255.0        -
#
#       accelerationTime fuelCapacity  speed payload  trailerWeight  \
# 0                  7.5          NaN   150   #NAME?          1720
# 1                  7.8          NaN   150   #NAME?          1770
# 2                  7.8          NaN   150   #NAME?          1770
# 3                  8.6         3319   235     435           1610
# 4                 17.2         1189   128     670            930
# ...                ...          ...    ...     ...            ...
# 16128              3.7         3996   295   #NAME?          1078
# 16129              4.2         3605   290   #NAME?          1100
# 16130              3.9         3996   314   #NAME?          1150
# 16131              4.1         4997   267     170           1080
# 16132              4.8         3950   235     170           1080
#
#          vEengineType vEengineDisplacement torque
# 0      electric motor                  NaN    310
# 1      electric motor                  NaN    310
# 2      electric motor                  NaN    310
# 3         fuel engine                 3319    309
# 4         fuel engine                 1189     97
# ...               ...                  ...    ...
# 16128     fuel engine                 3996    420
# 16129     fuel engine                 3605    390
# 16130     fuel engine                 3996    420
# 16131     fuel engine                 4997    490
# 16132     fuel engine                 3950   n.b.
#
# [16133 rows x 24 columns]

# %% [markdown]
# Loại bỏ các dòng bị lỗi, các dòng không lấy được dữ liệu

# %%
cars_data = cars_data[cars_data != '-']
cars_data
# Out:
#                       name   brand    price length height  width weightTotal  \
# 0      Aiways U5 Standaard  Aiways   39.083  4680   1700   1865          NaN
# 1        Aiways U5 Premium  Aiways   42.934  4680   1700   1865          NaN
# 2       Aiways U5 Showroom  Aiways   40.934  4680   1700   1865          NaN
# 3               Subaru SVX  Subaru   53.090  4625   1300   1770         2045
# 4       Subaru E-wagon AWD  Subaru   17.241  3525   1925   1415         1600
# ...                    ...     ...      ...    ...    ...    ...         ...
# 16128          TVR Sagaris     TVR  134.500  4060   1175   1770          NaN
# 16129           TVR Tuscan     TVR  105.500  4235   1200   1810          NaN
# 16130         TVR Tuscan S     TVR  109.900  4235   1200   1810          NaN
# 16131     TVR Griffith 500     TVR   71.187  3892   1205   1943         1250
# 16132     TVR Griffith 400     TVR   63.473  3892   1205   1943         1250
#
#        modelDate  fuelType  numberOfAxles  ...  cargoVolume roofLoad  \
# 0           2020       NaN              2  ...       1555.0       75
# 1           2020       NaN              2  ...       1555.0       75
# 2           2020       NaN              2  ...       1555.0       75
# 3           1992  gasoline              2  ...        466.0       50
# 4           1993  gasoline              2  ...          NaN       70
# ...          ...       ...            ...  ...          ...      ...
# 16128       2006  gasoline              2  ...        495.0      NaN
# 16129       2003  gasoline              2  ...        275.0      NaN
# 16130       2003  gasoline              2  ...        275.0      NaN
# 16131       1994  gasoline              2  ...        255.0      NaN
# 16132       1994  gasoline              2  ...        255.0      NaN
#
#       accelerationTime fuelCapacity  speed payload  trailerWeight  \
# 0                  7.5          NaN   150   #NAME?          1720
# 1                  7.8          NaN   150   #NAME?          1770
# 2                  7.8          NaN   150   #NAME?          1770
# 3                  8.6         3319   235     435           1610
# 4                 17.2         1189   128     670            930
# ...                ...          ...    ...     ...            ...
# 16128              3.7         3996   295   #NAME?          1078
# 16129              4.2         3605   290   #NAME?          1100
# 16130              3.9         3996   314   #NAME?          1150
# 16131              4.1         4997   267     170           1080
# 16132              4.8         3950   235     170           1080
#
#          vEengineType vEengineDisplacement torque
# 0      electric motor                  NaN    310
# 1      electric motor                  NaN    310
# 2      electric motor                  NaN    310
# 3         fuel engine                 3319    309
# 4         fuel engine                 1189     97
# ...               ...                  ...    ...
# 16128     fuel engine                 3996    420
# 16129     fuel engine                 3605    390
# 16130     fuel engine                 3996    420
# 16131     fuel engine                 4997    490
# 16132     fuel engine                 3950   n.b.
#
# [16133 rows x 24 columns]

# %%
cars_data = cars_data[cars_data != '#NAME?']
cars_data
# Out:
#                       name   brand    price length height  width weightTotal  \
# 0      Aiways U5 Standaard  Aiways   39.083  4680   1700   1865          NaN
# 1        Aiways U5 Premium  Aiways   42.934  4680   1700   1865          NaN
# 2       Aiways U5 Showroom  Aiways   40.934  4680   1700   1865          NaN
# 3               Subaru SVX  Subaru   53.090  4625   1300   1770         2045
# 4       Subaru E-wagon AWD  Subaru   17.241  3525   1925   1415         1600
# ...                    ...     ...      ...    ...    ...    ...         ...
# 16128          TVR Sagaris     TVR  134.500  4060   1175   1770          NaN
# 16129           TVR Tuscan     TVR  105.500  4235   1200   1810          NaN
# 16130         TVR Tuscan S     TVR  109.900  4235   1200   1810          NaN
# 16131     TVR Griffith 500     TVR   71.187  3892   1205   1943         1250
# 16132     TVR Griffith 400     TVR   63.473  3892   1205   1943         1250
#
#        modelDate  fuelType  numberOfAxles  ...  cargoVolume roofLoad  \
# 0           2020       NaN              2  ...       1555.0       75
# 1           2020       NaN              2  ...       1555.0       75
# 2           2020       NaN              2  ...       1555.0       75
# 3           1992  gasoline              2  ...        466.0       50
# 4           1993  gasoline              2  ...          NaN       70
# ...          ...       ...            ...  ...          ...      ...
# 16128       2006  gasoline              2  ...        495.0      NaN
# 16129       2003  gasoline              2  ...        275.0      NaN
# 16130       2003  gasoline              2  ...        275.0      NaN
# 16131       1994  gasoline              2  ...        255.0      NaN
# 16132       1994  gasoline              2  ...        255.0      NaN
#
#       accelerationTime fuelCapacity  speed payload  trailerWeight  \
# 0                  7.5          NaN   150      NaN          1720
# 1                  7.8          NaN   150      NaN          1770
# 2                  7.8          NaN   150      NaN          1770
# 3                  8.6         3319   235     435           1610
# 4                 17.2         1189   128     670            930
# ...                ...          ...    ...     ...            ...
# 16128              3.7         3996   295      NaN          1078
# 16129              4.2         3605   290      NaN          1100
# 16130              3.9         3996   314      NaN          1150
# 16131              4.1         4997   267     170           1080
# 16132              4.8         3950   235     170           1080
#
#          vEengineType vEengineDisplacement torque
# 0      electric motor                  NaN    310
# 1      electric motor                  NaN    310
# 2      electric motor                  NaN    310
# 3         fuel engine                 3319    309
# 4         fuel engine                 1189     97
# ...               ...                  ...    ...
# 16128     fuel engine                 3996    420
# 16129     fuel engine                 3605    390
# 16130     fuel engine                 3996    420
# 16131     fuel engine                 4997    490
# 16132     fuel engine                 3950   n.b.
#
# [16133 rows x 24 columns]

# %%
cars_data = cars_data[cars_data != 'n.b.']
cars_data
# Out:
#                       name   brand    price length height  width weightTotal  \
# 0      Aiways U5 Standaard  Aiways   39.083  4680   1700   1865          NaN
# 1        Aiways U5 Premium  Aiways   42.934  4680   1700   1865          NaN
# 2       Aiways U5 Showroom  Aiways   40.934  4680   1700   1865          NaN
# 3               Subaru SVX  Subaru   53.090  4625   1300   1770         2045
# 4       Subaru E-wagon AWD  Subaru   17.241  3525   1925   1415         1600
# ...                    ...     ...      ...    ...    ...    ...         ...
# 16128          TVR Sagaris     TVR  134.500  4060   1175   1770          NaN
# 16129           TVR Tuscan     TVR  105.500  4235   1200   1810          NaN
# 16130         TVR Tuscan S     TVR  109.900  4235   1200   1810          NaN
# 16131     TVR Griffith 500     TVR   71.187  3892   1205   1943         1250
# 16132     TVR Griffith 400     TVR   63.473  3892   1205   1943         1250
#
#        modelDate  fuelType  numberOfAxles  ...  cargoVolume roofLoad  \
# 0           2020       NaN              2  ...       1555.0       75
# 1           2020       NaN              2  ...       1555.0       75
# 2           2020       NaN              2  ...       1555.0       75
# 3           1992  gasoline              2  ...        466.0       50
# 4           1993  gasoline              2  ...          NaN       70
# ...          ...       ...            ...  ...          ...      ...
# 16128       2006  gasoline              2  ...        495.0      NaN
# 16129       2003  gasoline              2  ...        275.0      NaN
# 16130       2003  gasoline              2  ...        275.0      NaN
# 16131       1994  gasoline              2  ...        255.0      NaN
# 16132       1994  gasoline              2  ...        255.0      NaN
#
#       accelerationTime fuelCapacity  speed payload  trailerWeight  \
# 0                  7.5          NaN   150      NaN          1720
# 1                  7.8          NaN   150      NaN          1770
# 2                  7.8          NaN   150      NaN          1770
# 3                  8.6         3319   235     435           1610
# 4                 17.2         1189   128     670            930
# ...                ...          ...    ...     ...            ...
# 16128              3.7         3996   295      NaN          1078
# 16129              4.2         3605   290      NaN          1100
# 16130              3.9         3996   314      NaN          1150
# 16131              4.1         4997   267     170           1080
# 16132              4.8         3950   235     170           1080
#
#          vEengineType vEengineDisplacement torque
# 0      electric motor                  NaN    310
# 1      electric motor                  NaN    310
# 2      electric motor                  NaN    310
# 3         fuel engine                 3319    309
# 4         fuel engine                 1189     97
# ...               ...                  ...    ...
# 16128     fuel engine                 3996    420
# 16129     fuel engine                 3605    390
# 16130     fuel engine                 3996    420
# 16131     fuel engine                 4997    490
# 16132     fuel engine                 3950    NaN
#
# [16133 rows x 24 columns]

# %%
cars_data = cars_data[cars_data != 't']
cars_data
# Out:
#                       name   brand    price length height  width weightTotal  \
# 0      Aiways U5 Standaard  Aiways   39.083  4680   1700   1865          NaN
# 1        Aiways U5 Premium  Aiways   42.934  4680   1700   1865          NaN
# 2       Aiways U5 Showroom  Aiways   40.934  4680   1700   1865          NaN
# 3               Subaru SVX  Subaru   53.090  4625   1300   1770         2045
# 4       Subaru E-wagon AWD  Subaru   17.241  3525   1925   1415         1600
# ...                    ...     ...      ...    ...    ...    ...         ...
# 16128          TVR Sagaris     TVR  134.500  4060   1175   1770          NaN
# 16129           TVR Tuscan     TVR  105.500  4235   1200   1810          NaN
# 16130         TVR Tuscan S     TVR  109.900  4235   1200   1810          NaN
# 16131     TVR Griffith 500     TVR   71.187  3892   1205   1943         1250
# 16132     TVR Griffith 400     TVR   63.473  3892   1205   1943         1250
#
#        modelDate  fuelType  numberOfAxles  ...  cargoVolume roofLoad  \
# 0           2020       NaN              2  ...       1555.0       75
# 1           2020       NaN              2  ...       1555.0       75
# 2           2020       NaN              2  ...       1555.0       75
# 3           1992  gasoline              2  ...        466.0       50
# 4           1993  gasoline              2  ...          NaN       70
# ...          ...       ...            ...  ...          ...      ...
# 16128       2006  gasoline              2  ...        495.0      NaN
# 16129       2003  gasoline              2  ...        275.0      NaN
# 16130       2003  gasoline              2  ...        275.0      NaN
# 16131       1994  gasoline              2  ...        255.0      NaN
# 16132       1994  gasoline              2  ...        255.0      NaN
#
#       accelerationTime fuelCapacity  speed payload  trailerWeight  \
# 0                  7.5          NaN   150      NaN          1720
# 1                  7.8          NaN   150      NaN          1770
# 2                  7.8          NaN   150      NaN          1770
# 3                  8.6         3319   235     435           1610
# 4                 17.2         1189   128     670            930
# ...                ...          ...    ...     ...            ...
# 16128              3.7         3996   295      NaN          1078
# 16129              4.2         3605   290      NaN          1100
# 16130              3.9         3996   314      NaN          1150
# 16131              4.1         4997   267     170           1080
# 16132              4.8         3950   235     170           1080
#
#          vEengineType vEengineDisplacement torque
# 0      electric motor                  NaN    310
# 1      electric motor                  NaN    310
# 2      electric motor                  NaN    310
# 3         fuel engine                 3319    309
# 4         fuel engine                 1189     97
# ...               ...                  ...    ...
# 16128     fuel engine                 3996    420
# 16129     fuel engine                 3605    390
# 16130     fuel engine                 3996    420
# 16131     fuel engine                 4997    490
# 16132     fuel engine                 3950    NaN
#
# [16133 rows x 24 columns]

# %%
cars_data = cars_data.dropna()
cars_data
# Out:
#                                                  name   brand   price length  \
# 3                                          Subaru SVX  Subaru  53.090  4625
# 5                      Subaru Impreza 2.5 WRX STi AWD  Subaru  52.285  4465
# 6                             Subaru Impreza 2.0R AWD  Subaru  26.565  4465
# 7                             Subaru Impreza 2.0R AWD  Subaru  28.565  4465
# 8                          Subaru Impreza 2.5 WRX AWD  Subaru  33.785  4465
# ...                                               ...     ...     ...    ...
# 16120  Seat Leon SC 2.0 TDI 184hp FR Business Intense    Seat  35.210  4246
# 16121        Seat Leon SC 1.8 TSI FR Business Intense    Seat  31.110  4246
# 16122                  Seat Leon SC 2.0 TSI Cupra 300    Seat  43.560  4236
# 16123                   Seat Leon SC 2.0 TDI 184hp FR    Seat  34.910  4246
# 16124                         Seat Leon SC 1.8 TSI FR    Seat  30.810  4246
#
#       height  width weightTotal  modelDate  fuelType  numberOfAxles  ...  \
# 3      1300   1770         2045       1992  gasoline              2  ...
# 5      1440   1740         1900       2005  gasoline              2  ...
# 6      1440   1740         1780       2005  gasoline              2  ...
# 7      1440   1740         1780       2005  gasoline              2  ...
# 8      1440   1740         1860       2005  gasoline              2  ...
# ...      ...    ...         ...        ...       ...            ...  ...
# 16120  1431   1810         1860       2017    diesel              2  ...
# 16121  1431   1810         1830       2017  gasoline              2  ...
# 16122  1423   1810         1890       2017  gasoline              2  ...
# 16123  1431   1810         1860       2017    diesel              2  ...
# 16124  1431   1810         1830       2017  gasoline              2  ...
#
#        cargoVolume roofLoad accelerationTime fuelCapacity  speed payload  \
# 3            466.0       50              8.6         3319   235     435
# 5            395.0       80              5.4         2457   255     430
# 6            401.0       80              8.8         1994   210     490
# 7            401.0       80             11.6         1994   191     450
# 8            401.0       80              5.9         2457   230     480
# ...            ...      ...              ...          ...    ...     ...
# 16120       1210.0       75              7.4         1968   228     610
# 16121       1210.0       75              7.4         1798   226     640
# 16122       1210.0       75              5.6         1984   250     595
# 16123       1210.0       75              7.4         1968   228     610
# 16124       1210.0       75              7.4         1798   226     640
#
#        trailerWeight vEengineType vEengineDisplacement torque
# 3              1610   fuel engine                 3319    309
# 5              1470   fuel engine                 2457    392
# 6              1290   fuel engine                 1994    186
# 7              1330   fuel engine                 1994    186
# 8              1380   fuel engine                 2457    320
# ...              ...          ...                  ...    ...
# 16120          1250   fuel engine                 1968    380
# 16121          1190   fuel engine                 1798    250
# 16122          1295   fuel engine                 1984    380
# 16123          1250   fuel engine                 1968    380
# 16124          1190   fuel engine                 1798    250
#
# [12913 rows x 24 columns]

# %% [markdown]
# Lưu lại thành csv

# %%
cars_data.to_csv('cars_data_processed.csv',sep = '\t')

# %% [markdown]
# Load Data đã được xử lý

# %%
import pandas as pd

# %%
data = pd.read_csv('cars_data_processed.csv',sep = '\t',encoding='utf-8')
data
# Out:
#        Unnamed: 0                                            name   brand  \
# 0               3                                      Subaru SVX  Subaru
# 1               5                  Subaru Impreza 2.5 WRX STi AWD  Subaru
# 2               6                         Subaru Impreza 2.0R AWD  Subaru
# 3               7                         Subaru Impreza 2.0R AWD  Subaru
# 4               8                      Subaru Impreza 2.5 WRX AWD  Subaru
# ...           ...                                             ...     ...
# 12908       16120  Seat Leon SC 2.0 TDI 184hp FR Business Intense    Seat
# 12909       16121        Seat Leon SC 1.8 TSI FR Business Intense    Seat
# 12910       16122                  Seat Leon SC 2.0 TSI Cupra 300    Seat
# 12911       16123                   Seat Leon SC 2.0 TDI 184hp FR    Seat
# 12912       16124                         Seat Leon SC 1.8 TSI FR    Seat
#
#         price  length  height  width  weightTotal  modelDate  fuelType  ...  \
# 0      53.090    4625    1300   1770         2045       1992  gasoline  ...
# 1      52.285    4465    1440   1740         1900       2005  gasoline  ...
# 2      26.565    4465    1440   1740         1780       2005  gasoline  ...
# 3      28.565    4465    1440   1740         1780       2005  gasoline  ...
# 4      33.785    4465    1440   1740         1860       2005  gasoline  ...
# ...       ...     ...     ...    ...          ...        ...       ...  ...
# 12908  35.210    4246    1431   1810         1860       2017    diesel  ...
# 12909  31.110    4246    1431   1810         1830       2017  gasoline  ...
# 12910  43.560    4236    1423   1810         1890       2017  gasoline  ...
# 12911  34.910    4246    1431   1810         1860       2017    diesel  ...
# 12912  30.810    4246    1431   1810         1830       2017  gasoline  ...
#
#        cargoVolume  roofLoad  accelerationTime fuelCapacity speed  payload  \
# 0            466.0        50               8.6         3319   235      435
# 1            395.0        80               5.4         2457   255      430
# 2            401.0        80               8.8         1994   210      490
# 3            401.0        80              11.6         1994   191      450
# 4            401.0        80               5.9         2457   230      480
# ...            ...       ...               ...          ...   ...      ...
# 12908       1210.0        75               7.4         1968   228      610
# 12909       1210.0        75               7.4         1798   226      640
# 12910       1210.0        75               5.6         1984   250      595
# 12911       1210.0        75               7.4         1968   228      610
# 12912       1210.0        75               7.4         1798   226      640
#
#        trailerWeight  vEengineType  vEengineDisplacement  torque
# 0               1610   fuel engine                  3319     309
# 1               1470   fuel engine                  2457     392
# 2               1290   fuel engine                  1994     186
# 3               1330   fuel engine                  1994     186
# 4               1380   fuel engine                  2457     320
# ...              ...           ...                   ...     ...
# 12908           1250   fuel engine                  1968     380
# 12909           1190   fuel engine                  1798     250
# 12910           1295   fuel engine                  1984     380
# 12911           1250   fuel engine                  1968     380
# 12912           1190   fuel engine                  1798     250
#
# [12913 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12913 entries, 0 to 12912
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            12913 non-null  int64
#  1   name                  12913 non-null  object
#  2   brand                 12913 non-null  object
#  3   price                 12913 non-null  float64
#  4   length                12913 non-null  int64
#  5   height                12913 non-null  int64
#  6   width                 12913 non-null  int64
#  7   weightTotal           12913 non-null  int64
#  8   modelDate             12913 non-null  int64
#  9   fuelType              12913 non-null  object
#  10  numberOfAxles         12913 non-null  int64
#  11  numberOfDoors         12913 non-null  int64
#  12  numberOfForwardGears  12913 non-null  int64
#  13  seatingCapacity       12913 non-null  object
#  14  vehicleTransmission   12913 non-null  object
#  15  cargoVolume           12913 non-null  float64
#  16  roofLoad              12913 non-null  int64
#  17  accelerationTime      12913 non-null  float64
#  18  fuelCapacity          12913 non-null  int64
#  19  speed                 12913 non-null  int64
#  20  payload               12913 non-null  int64
#  21  trailerWeight         12913 non-null  int64
#  22  vEengineType          12913 non-null  object
#  23  vEengineDisplacement  12913 non-null  int64
#  24  torque                12913 non-null  int64
# dtypes: float64(3), int64(16), object(6)
# memory usage: 2.5+ MB
